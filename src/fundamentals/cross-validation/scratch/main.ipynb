# %%
# PATHs
BITCOIN_DATA = "H:/Visual-Studio-Code-Data/Python/machine-learning-journal/data/bitcon_data.csv"
GLOBAL_CARS_DATA = "H:/Visual-Studio-Code-Data/Python/machine-learning-journal/data/global_cars_data.csv"
DICTIONARY_ABBREVIATION_DATA = "H:/Visual-Studio-Code-Data/Python/machine-learning-journal/data/dictionary_abbreviation.csv"
TWITTER_EMOTION_DATA = "H:/Visual-Studio-Code-Data/Python/machine-learning-journal/data/twitter_emotion_data.csv"

# %%
import sys 
import pandas as pd
import numpy as np

if __name__ == "__main__" : 

    # get the argument of how many fold (k)
    k : int = 5

    # import data from the dataset
    df = pd.read_csv(BITCOIN_DATA) # read only

    # get how many data needed for the test
    n_test_data : int = (len(df) // k) + 1 # round upwards

    # do shuffle
    df_shuffle = df.sample(frac=1).reset_index(drop=True)

    # partition the data
    test_data = df_shuffle[:n_test_data]
    train_data = df_shuffle[n_test_data:]

    # partition into each and convert to numpy
    y_test = test_data[["Market Cap"]].to_numpy()
    X_test = test_data.drop("Market Cap", axis=1).to_numpy()
    y_train = train_data[["Market Cap"]].to_numpy()
    X_train = train_data.drop("Market Cap", axis=1).to_numpy()

    # split the data into x and y
    print("////////////// X train ////////////////")
    print(X_train)
    print("////////////// y train ////////////////")
    print(y_train)
    print("////////////// X test ////////////////")
    print(X_test)
    print("////////////// y test ////////////////")
    print(y_test)
# Out:
# ////////////// X train ////////////////
# [['2017-10-02' '2017-10-03' 4362.540620199 ... 4361.270625569
#   4384.188461181 1177332863.796909]
#  ['2011-04-16' '2011-04-17' 1.0499 ... 1.0499 1.0499 0.0]
#  ['2013-12-18' '2013-12-19' 678.2 ... 420.51 522.7 0.0]
#  ...
#  ['2016-10-21' '2016-10-22' 630.857 ... 630.694 632.896
#   55622919.512195125]
#  ['2023-03-03' '2023-03-04' 23466.6755 ... 22190.8158 22333.76670186151
#   49445760675.55556]
#  ['2011-10-09' '2011-10-10' 4.1029 ... 4.1029 4.1029 0.0]]
# ////////////// y train ////////////////
# [[7.35780315e+10]
#  [0.00000000e+00]
#  [6.90400442e+09]
#  ...
#  [1.00774385e+10]
#  [4.30799147e+11]
#  [0.00000000e+00]]
# ////////////// X test ////////////////
# [['2021-06-09' '2021-06-10' 33403.62668135009 ... 32431.61
#   37345.044921562585 72582508401.77777]
#  ['2021-01-14' '2021-01-15' 37394.122642209 ... 36882.027990631
#   39304.686213759 114931563480.27837]
#  ['2022-02-23' '2022-02-24' 38227.7774 ... 37088.33877587311
#   37287.4863427188 108954655658.66669]
#  ...
#  ['2022-05-01' '2022-05-02' 37636.0214183511 ... 37572.22979998869
#   38467.094 49695227037.82079]
#  ['2022-11-17' '2022-11-18' 16670.395122861475 ... 16448.1626
#   16690.889527338422 51656804096.0]
#  ['2012-01-15' '2012-01-16' 7.0018 ... 7.0018 7.0018 0.0]]
# ////////////// y test ////////////////
# [[6.52523328e+11]
#  [7.16637812e+11]
#  [7.24585420e+11]
#  ...
#  [7.23843146e+11]
#  [3.19058775e+11]
#  [0.00000000e+00]]
